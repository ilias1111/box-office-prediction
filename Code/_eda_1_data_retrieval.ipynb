# %%
import pandas as pd
from IPython.display import display
from eda_support_functions import *

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 200)

# %%
wikipedia_movie_financial_data = pd.read_csv(
    "../data/retrieved_data/wikipedia/movie_financial_data.csv"
).drop(columns="Unnamed: 0")
wikipedia_movie_financial_data_usd = pd.read_csv(
    "../data/retrieved_data/wikipedia/movie_financial_data_usd.csv"
)


movie = pd.read_csv("../data/retrieved_data/tmdb/movies.csv")
genres = pd.read_csv("../data/retrieved_data/tmdb/genres.csv")
keywords = pd.read_csv("../data/retrieved_data/tmdb/keywords.csv")
cast = pd.read_csv("../data/retrieved_data/tmdb/cast.csv")
collections = pd.read_csv("../data/retrieved_data/tmdb/collections.csv")
production_companies = pd.read_csv("../data/retrieved_data/tmdb/production_companies.csv")
release_dates = pd.read_csv("../data/retrieved_data/tmdb/release_dates.csv")
spoken_languages = pd.read_csv("../data/retrieved_data/tmdb/spoken_languages.csv")
production_countries = pd.read_csv("../data/retrieved_data/tmdb/production_countries.csv")
mojo = pd.read_csv("../data/manual_data/parsed_mojo.csv").rename(
    columns={"Unnamed: 0": "imdb_id", "worldwide": "revenue_mojo"}
)

# %%
mojo
# Out:
#          imdb_id  international  revenue_mojo   domestic  \
# 0      tt0421045            0.0           0.0        0.0
# 1      tt1091207            0.0           0.0        0.0
# 2      tt0473024            0.0     7009668.0  7009668.0
# 3      tt1879066            0.0           0.0        0.0
# 4      tt0119053            0.0     6136856.0  6136856.0
# ...          ...            ...           ...        ...
# 11167  tt1401668            NaN           NaN        NaN
# 11168  tt1972571            NaN           NaN        NaN
# 11169  tt0114959            NaN           NaN        NaN
# 11170  tt0084290            NaN           NaN        NaN
# 11171  tt0112924            NaN           NaN        NaN
#
#                                                    error
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11167  RetryError[<Future at 0x3e6ae1f49040 state=fin...
# 11168  RetryError[<Future at 0x3e6ad11c2d30 state=fin...
# 11169  RetryError[<Future at 0x3e5a6f760580 state=fin...
# 11170  RetryError[<Future at 0x3e29315cd310 state=fin...
# 11171  RetryError[<Future at 0x3eef07918f70 state=fin...
#
# [11172 rows x 5 columns]

# %%
manual_adjustments = pd.read_csv("../data/manual_data/manual_adjustments.csv")
manual_adjustments = manual_adjustments[
    ["movie_id", "revenue_fix", "budget_fix"]
].fillna(0)

# %%
# Print how many movies in wikipedia_movie_financial_data
print(
    f"Number of movies in wikipedia_movie_financial_data: {len(wikipedia_movie_financial_data)}"
)
unique_imdb_ids = wikipedia_movie_financial_data["tmdb_id"].unique()
print(
    f"Number of unique imdb_ids in wikipedia_movie_financial_data: {len(unique_imdb_ids)}"
)
# Out:
# Number of movies in wikipedia_movie_financial_data: 43355
# Number of unique imdb_ids in wikipedia_movie_financial_data: 43355

# %%
# #load json from url into dataframe
# import requests
# import json
# url = 'https://ffbe7889f116f85ae79fd90903cf7cccfd41509ca2fe525c2cbda26-apidata.googleusercontent.com/download/storage/v1/b/movie-dataset-291206-movie-data-results/o/20240714_094035_aggregated_results.json?jk=AYBlUPBJApueiHReA-hfruhHxgh8ghoMyS56g-SXJFQSLSg4fymkM4dgnxV6XZyyLQuP54YFFyIEjVmx_Q4oG5jGu3cxPMi2UMXB2FR_DARj-6blknNhuXaBHp6tCXf0HYtxwrC7yklq7U2a8NBQFFf9sLik7i5I1JNWLEe7tDOrU1rAKTNmstj9T9EAWAkX8ULAKB51HFE_mf1TN6NsCEnt_wvWpnY7kufRoI2c-NiLrckk5RGoUnXIiwQF5PP1BIRyIMTHrPm_qeE9s8hnSViNFc0rfhHO0BsIe559FqnDEdIhux07QUfh2DARX8dXKo0Mmb_YHCx368SaexGNydOzAGkfPwhLV9T914KDMwOOOp-H2BPm1kKFKyUc9zdzVQx-dA4RSzvvZn7Ti6n5xPpDhHfgMQe-zI0aRezkwpS6UvdCilkarNR5Mz-5M9Pst9Mqil25h-_2D88ALyROA5090E-iyursRs8smId5NE21LkTHcIBZb1-L9XMhsaJw701dzR7AaKZO2vdh0IouEiBJyWCFTmjDiZ2QJXlM6ssEWyMEQZGl5f17BiXTI2RzO-XnuaWPgJ3uulaOa7OijKsMQYt9mZg6G5usx7B8oDwV2TtkTepqBJvMztVC1iVJ2HgE3VR-tPNkP3TXvsELbYcX4OM1XlOJ-ombTOamS-nQsbH7NKLUCxF3yhOGtFbtMaHt7A9Uv6jr0XKkXiw3YrW9H-AdVMrzqbHKzU5PrWJV0NC_JVkI6fK8t_XweMN_Du--nZOTtdsYLkeiR3iZ2LeBxneKkxgbnAwKBnv0gVRtcrP54C55EwKWkdrf7yAnl6DQBBRZRCZCcZwliv01gHXG4AcKbYLCl3dPotdBR_VvGMEkq6MZ1GQI639GSYhl_38fUBix884nosRXiog4V5m8c__hz1boaESxkpo89QO8Y-IFgFYm1_uMfzxxwHAn0hkRjD692jfEowJcn_2p7i3lN-6CnM6aZONYoYCfTVMIfFm8IuZKWyCHYABunDXgDd5iquPYOrLFFFOFPcqd9RF-jQJQ_P49NoA_ITCEGQK44veox7bbpI0Pbju6zHpTswIFEESbyLbHFmFjLiVMQGVCP51J5Do79r-aT7DkKNTskdrm4mzSpLN9aPEN5CxgqB_cNj9xaxB8W36AIximjr08S9_6un6P4dxUFFmconT0bWxel1kcQZV-zyvt6mSGuhegE-fXPFY8bVaI4dYtQYURdhf2RVC8&isca=1'
# response = requests.get(url)
# data = response.json()
# # print(data)
# mojo = pd.read_json(json.dumps(data), orient='index')

# mojo.to_csv('../data/manual_data/parsed_mojo.csv')

# %% [markdown]
# # Wikipedia

# %%
# Check wikipedia_movie_financial_data for duplicates on tmdb_id
display(
    wikipedia_movie_financial_data[
        wikipedia_movie_financial_data.duplicated(subset=["tmdb_id"], keep=False)
    ]
)

# How many unique tmdb_ids are duplicated?
print(
    wikipedia_movie_financial_data[
        wikipedia_movie_financial_data.duplicated(subset=["tmdb_id"], keep=False)
    ]["tmdb_id"].nunique()
)
# Out:
# Empty DataFrame
# Columns: [url, tmdb_id, budget_original_string, budget_currency, budget_min, budget_max, budget_avg, budget_error, box_office_original_string, box_office_currency, box office_min, box_office_max, box_office_avg, box_office_error, external_links, error, box_office_min]
# Index: []
# 0

# %%
wikipedia_movie_financial_data.groupby(by=["budget_currency"]).size().sort_values(
    ascending=False
).head(20)
# Out:
# budget_currency
# USD    10518
# INR      828
# EUR      601
# GBP      447
# AUD      217
# CAD      110
# BRL      106
# JPY       79
# SEK       54
# KRW       44
# RUB       43
# HKD       39
# CZK       31
# DEM       28
# ESP       27
# PHP       24
# NOK       19
# NGN       16
# DKK       14
# CHF       14
# dtype: int64

# %%
wikipedia_movie_financial_data.groupby(by=["box_office_currency"]).size().sort_values(
    ascending=False
).head(20)
# Out:
# box_office_currency
# USD    13193
# INR      919
# HKD      290
# JPY      254
# AUD      176
# GBP      167
# EUR      123
# ITL      115
# BRL       86
# PHP       57
# SEK       32
# RUB       31
# ESP       28
# NGN       24
# CHF       23
# CZK       18
# CAD       17
# DEM       10
# TRY       10
# KRW        9
# dtype: int64

# %%
wikipedia_movie_financial_data[
    (wikipedia_movie_financial_data["budget_currency"].isnull())
    & (wikipedia_movie_financial_data["budget_original_string"].notnull())
]["budget_original_string"].value_counts()[:70]
# Out:
# budget_original_string
# Unknown                                             8
# IL3 million                                         7
# P208,120,000                                        2
# MYR 2.5 million                                     2
# ƒ 5 million                                         1
# Lit. 15 billion[2]                                  1
# 1.3 million Rbls                                    1
# (est.) 18 million[1]                                1
# 622,000 Rbls[2]                                     1
# 1 million Rbls[2]                                   1
# P100 million                                        1
# 150 million lire                                    1
# ₣3 million                                          1
# 11,6 million guilders[1]                            1
# ₣120-140million                                     1
# L.12 billion[1]                                     1
# 1,000,000                                           1
# Rs. 270 million                                     1
# 20,000,000 Kč                                       1
# 100000                                              1
# 11 crore\n[2]                                       1
# ISK 200,000,000                                     1
# 3.6 million [1]                                     1
# N/A[1]                                              1
# TL 50,000,000                                       1
# Rs. 7 crores                                        1
# 1.2 million (estimated)                             1
# [1]                                                 1
# [Unknown]                                           1
# 20.000.000 lire (according to George Eastman)[1]    1
# ROL33,000,000 (estimated)                           1
# 2.5 crore[1]                                        1
# 25000                                               1
# 2.1 million litas                                   1
# ~ Rp10 billion                                      1
# Rp 3.5 billion                                      1
# ISK200,000,000                                      1
# 6.5 Million                                         1
# 500,000 (estimated)                                 1
# 19 million EEK                                      1
# 32 million EEK                                      1
# RS3 million[2]                                      1
# 8,000,000                                           1
# Kč35 million                                        1
# 4,300,000 KČs[1]                                    1
# FIM 5,970,646[1]                                    1
# MYR 1.3 Million                                     1
# MYR 1.3 million                                     1
# 15,000,000 Kč[2]                                    1
# ₪7,684,104                                          1
# {{currency}} – invalid amount (help)[1]             1
# 900.000 TL                                          1
# 8.5 million mk[1]                                   1
# 9 million CSK[1]                                    1
# FIM1,6 million                                      1
# FIM 5,2 million[1]                                  1
# VEN 3,000,000,000[1]                                1
# 2 billion lire                                      1
# 49,200,000 Rbls                                     1
# RUR 6.5 million                                     1
# 16,000,000 L.E                                      1
# 7,000,000 (Estimated)[1]                            1
# RUR 10 million                                      1
# FIM 6,130,062[1]                                    1
# 12 million mk[1]                                    1
# MYR 1.82 million[1]                                 1
# ISK 130,000,000                                     1
# MYR 1.51 million[1]                                 1
# RM 64,000                                           1
# 12.7 M NIS                                          1
# Name: count, dtype: int64

# %%
print(
    f"Number of revenue_mojo columns not with 0 values: {(mojo['revenue_mojo'] != 0).sum()}"
)
print(f"Number of cases with error: {(~mojo['error'].isna()).sum()}")
# Out:
# Number of revenue_mojo columns not with 0 values: 5931
# Number of cases with error: 23

# %%
mojo = mojo[["imdb_id", "revenue_mojo", "error"]]
movie = movie.merge(mojo, on="imdb_id", how="left")
movie["revenue_mojo"] = movie["revenue_mojo"].fillna(0)

wikipedia_movie_financial_data_usd_raw = wikipedia_movie_financial_data_usd.copy()
wikipedia_movie_financial_data_usd = wikipedia_movie_financial_data_usd[
    ["movie_id", "budget_avg_usd", "box_office_avg_usd", "url"]
].rename(
    columns={
        "budget_avg_usd": "budget_wiki",
        "box_office_avg_usd": "revenue_wiki",
        "url": "url_wiki",
    }
)
movie = movie.merge(wikipedia_movie_financial_data_usd, on="movie_id", how="left")
movie = movie.merge(manual_adjustments, on="movie_id", how="left")
movie["budget_wiki"] = movie["budget_wiki"].fillna(0).astype(int)
movie["revenue_wiki"] = movie["revenue_wiki"].fillna(0).astype(int)
movie["revenue_fix"] = movie["revenue_fix"].fillna(0).astype(int)
movie["budget_fix"] = movie["budget_fix"].fillna(0).astype(int)

# %%
# Replace the 0 values with the values from the wikipedia dataset
movie["budget_synthetic"] = movie["budget_fix"].replace(0, np.nan)
movie["budget_synthetic"] = (
    movie["budget_synthetic"].fillna(movie["budget"]).replace(0, np.nan)
)
movie["budget_synthetic"] = (
    movie["budget_synthetic"].fillna(movie["budget_wiki"]).fillna(0).astype(int)
)

# Create synthetic box office
movie["revenue_synthetic"] = movie["revenue_fix"].replace(0, np.nan)
movie["revenue_synthetic"] = (
    movie["revenue_synthetic"].fillna(movie["revenue_mojo"]).replace(0, np.nan)
)
movie["revenue_synthetic"] = (
    movie["revenue_synthetic"].fillna(movie["revenue"]).replace(0, np.nan)
)
movie["revenue_synthetic"] = (
    movie["revenue_synthetic"].fillna(movie["revenue_wiki"]).fillna(0).astype(int)
)

# %%
print("TMDB Data")
print(f"Number of tmdb revenue column not 0: {(movie['revenue'] != 0).sum()}")
print(f"Number of tmdb budget column not 0: {(movie['budget'] != 0).sum()}")
print(
    f"Number of revenue and budget not 0 : {((movie['revenue'] != 0) & (movie['budget'] != 0)).sum()}"
)

print("Mojo Enriched")
print(f"Number of mojo revenue column not 0: {(movie['revenue_mojo'] != 0).sum()}")
print(
    f"Number of revenue not 0: {((movie['revenue'] != 0) | (movie['revenue_mojo'] != 0)).sum()}"
)
print(
    f"Number of revenue and budget not 0 : {(((movie['revenue'] != 0) | (movie['revenue_mojo'] != 0)) & (movie['budget'] != 0)).sum()}"
)

print("Wikipedia Enriched")
print(f"Number of revenue column not 0: {(movie['revenue_synthetic'] != 0).sum()}")
print(f"Number of budget column not 0: {(movie['budget_synthetic'] != 0).sum()}")
print(
    f"Number of revenue and budget not 0 : {((movie['revenue_synthetic'] != 0) & (movie['budget_synthetic'] != 0)).sum()}"
)
# Out:
# TMDB Data
# Number of tmdb revenue column not 0: 11590
# Number of tmdb budget column not 0: 11734
# Number of revenue and budget not 0 : 7669
# Mojo Enriched
# Number of mojo revenue column not 0: 5907
# Number of revenue not 0: 14666
# Number of revenue and budget not 0 : 8020
# Wikipedia Enriched
# Number of revenue column not 0: 19820
# Number of budget column not 0: 16569
# Number of revenue and budget not 0 : 12193

# %%
compare = movie[(movie["revenue"] != 0) & (movie["revenue_mojo"] != 0)].copy()
compare["revenue_diff"] = compare["revenue"] - compare["revenue_mojo"]

# Calulate metrics
compare["revenue_diff"] = compare["revenue"] - compare["revenue_mojo"]
compare["revenue_ratio"] = compare["revenue"] / compare["revenue_mojo"]
compare["revenue_diff_ratio"] = compare["revenue_diff"] / compare["revenue_mojo"]

# Display
display(
    compare[
        [
            "imdb_id",
            "movie_id",
            "revenue",
            "revenue_mojo",
            "revenue_diff",
            "revenue_ratio",
            "revenue_diff_ratio",
        ]
    ]
    .sort_values(by="revenue_diff_ratio", ascending=False)
    .head(10)
)

# Describe
compare[["revenue_diff_ratio", "revenue_ratio", "revenue_diff"]].describe(
    percentiles=[0.01, 0.05, 0.1, 0.25, 0.5, 0.75, 0.9, 0.95, 0.97, 0.98, 0.99]
).style.format("{:.2f}")
# Out:
#          imdb_id  movie_id   revenue  revenue_mojo  revenue_diff  \
# 26969  tt0080516     13550  12000000         147.0    11999853.0
# 11329  tt0066769     10514  12376563         430.0    12376133.0
# 21072  tt0070723     12101   3600000         210.0     3599790.0
# 27991  tt0080310     13783   8200000         948.0     8199052.0
# 13712  tt0074695     10839   1509000         201.0     1508799.0
# 60115  tt0068638      5916  36734619        9588.0    36725031.0
# 37796  tt0082464     16124   1400000         394.0     1399606.0
# 56261  tt5125414    496681   7082000        3403.0     7078597.0
# 37040  tt0080117       233  23000000       14492.0    22985508.0
# 41036  tt0071222     16938   4000000        2686.0     3997314.0
#
#        revenue_ratio  revenue_diff_ratio
# 26969   81632.653061        81631.653061
# 11329   28782.704651        28781.704651
# 21072   17142.857143        17141.857143
# 27991    8649.789030         8648.789030
# 13712    7507.462687         7506.462687
# 60115    3831.311952         3830.311952
# 37796    3553.299492         3552.299492
# 56261    2081.104907         2080.104907
# 37040    1587.082528         1586.082528
# 41036    1489.203276         1488.203276
# <style type="text/css">
# </style>
# <table id="T_a12da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a12da_level0_col0" class="col_heading level0 col0" >revenue_diff_ratio</th>
#       <th id="T_a12da_level0_col1" class="col_heading level0 col1" >revenue_ratio</th>
#       <th id="T_a12da_level0_col2" class="col_heading level0 col2" >revenue_diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a12da_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_a12da_row0_col0" class="data row0 col0" >2831.00</td>
#       <td id="T_a12da_row0_col1" class="data row0 col1" >2831.00</td>
#       <td id="T_a12da_row0_col2" class="data row0 col2" >2831.00</td>
#     </tr>
#     <tr>
#       <th id="T_a12da_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_a12da_row1_col0" class="data row1 col0" >57.61</td>
#       <td id="T_a12da_row1_col1" class="data row1 col1" >58.61</td>
#       <td id="T_a12da_row1_col2" class="data row1 col2" >182207.69</td>
#     </tr>
#     <tr>
#       <th id="T_a12da_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_a12da_row2_col0" class="data row2 col0" >1675.89</td>
#       <td id="T_a12da_row2_col1" class="data row2 col1" >1675.89</td>
#       <td id="T_a12da_row2_col2" class="data row2 col2" >8766645.13</td>
#     </tr>
#     <tr>
#       <th id="T_a12da_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_a12da_row3_col0" class="data row3 col0" >-1.00</td>
#       <td id="T_a12da_row3_col1" class="data row3 col1" >0.00</td>
#       <td id="T_a12da_row3_col2" class="data row3 col2" >-182986582.00</td>
#     </tr>
#     <tr>
#       <th id="T_a12da_level0_row4" class="row_heading level0 row4" >1%</th>
#       <td id="T_a12da_row4_col0" class="data row4 col0" >-1.00</td>
#       <td id="T_a12da_row4_col1" class="data row4 col1" >0.00</td>
#       <td id="T_a12da_row4_col2" class="data row4 col2" >-20276382.90</td>
#     </tr>
#     <tr>
#       <th id="T_a12da_level0_row5" class="row_heading level0 row5" >5%</th>
#       <td id="T_a12da_row5_col0" class="data row5 col0" >-0.64</td>
#       <td id="T_a12da_row5_col1" class="data row5 col1" >0.36</td>
#       <td id="T_a12da_row5_col2" class="data row5 col2" >-3217484.00</td>
#     </tr>
#     <tr>
#       <th id="T_a12da_level0_row6" class="row_heading level0 row6" >10%</th>
#       <td id="T_a12da_row6_col0" class="data row6 col0" >-0.25</td>
#       <td id="T_a12da_row6_col1" class="data row6 col1" >0.75</td>
#       <td id="T_a12da_row6_col2" class="data row6 col2" >-1024850.00</td>
#     </tr>
#     <tr>
#       <th id="T_a12da_level0_row7" class="row_heading level0 row7" >25%</th>
#       <td id="T_a12da_row7_col0" class="data row7 col0" >-0.00</td>
#       <td id="T_a12da_row7_col1" class="data row7 col1" >1.00</td>
#       <td id="T_a12da_row7_col2" class="data row7 col2" >-33846.50</td>
#     </tr>
#     <tr>
#       <th id="T_a12da_level0_row8" class="row_heading level0 row8" >50%</th>
#       <td id="T_a12da_row8_col0" class="data row8 col0" >0.00</td>
#       <td id="T_a12da_row8_col1" class="data row8 col1" >1.00</td>
#       <td id="T_a12da_row8_col2" class="data row8 col2" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_a12da_level0_row9" class="row_heading level0 row9" >75%</th>
#       <td id="T_a12da_row9_col0" class="data row9 col0" >0.00</td>
#       <td id="T_a12da_row9_col1" class="data row9 col1" >1.00</td>
#       <td id="T_a12da_row9_col2" class="data row9 col2" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_a12da_level0_row10" class="row_heading level0 row10" >90%</th>
#       <td id="T_a12da_row10_col0" class="data row10 col0" >0.00</td>
#       <td id="T_a12da_row10_col1" class="data row10 col1" >1.00</td>
#       <td id="T_a12da_row10_col2" class="data row10 col2" >40492.00</td>
#     </tr>
#     <tr>
#       <th id="T_a12da_level0_row11" class="row_heading level0 row11" >95%</th>
#       <td id="T_a12da_row11_col0" class="data row11 col0" >0.35</td>
#       <td id="T_a12da_row11_col1" class="data row11 col1" >1.35</td>
#       <td id="T_a12da_row11_col2" class="data row11 col2" >2162493.00</td>
#     </tr>
#     <tr>
#       <th id="T_a12da_level0_row12" class="row_heading level0 row12" >97%</th>
#       <td id="T_a12da_row12_col0" class="data row12 col0" >1.46</td>
#       <td id="T_a12da_row12_col1" class="data row12 col1" >2.46</td>
#       <td id="T_a12da_row12_col2" class="data row12 col2" >7446909.40</td>
#     </tr>
#     <tr>
#       <th id="T_a12da_level0_row13" class="row_heading level0 row13" >98%</th>
#       <td id="T_a12da_row13_col0" class="data row13 col0" >3.83</td>
#       <td id="T_a12da_row13_col1" class="data row13 col1" >4.83</td>
#       <td id="T_a12da_row13_col2" class="data row13 col2" >18213929.00</td>
#     </tr>
#     <tr>
#       <th id="T_a12da_level0_row14" class="row_heading level0 row14" >99%</th>
#       <td id="T_a12da_row14_col0" class="data row14 col0" >45.93</td>
#       <td id="T_a12da_row14_col1" class="data row14 col1" >46.93</td>
#       <td id="T_a12da_row14_col2" class="data row14 col2" >32454406.60</td>
#     </tr>
#     <tr>
#       <th id="T_a12da_level0_row15" class="row_heading level0 row15" >max</th>
#       <td id="T_a12da_row15_col0" class="data row15 col0" >81631.65</td>
#       <td id="T_a12da_row15_col1" class="data row15 col1" >81632.65</td>
#       <td id="T_a12da_row15_col2" class="data row15 col2" >108046816.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
null_percentage_all = movie.isnull().mean() * 100

zero_percentage_all = (movie == 0).mean() * 100

null_zero_percentage_all = pd.DataFrame(
    {"Null Percentage": null_percentage_all, "Zero Percentage": zero_percentage_all}
)
print(null_zero_percentage_all)
# Out:
#                    Null Percentage  Zero Percentage
# movie_id                  0.000000         0.000000
# title                     0.000000         0.000000
# original_title            0.000000         0.000000
# original_language         0.000000         0.000000
# overview                  5.721179         0.000000
# tagline                  63.975073         0.000000
# release_date              0.238321         0.000000
# runtime                   0.000000         5.493220
# budget                    0.000000        82.630706
# revenue                   0.000000        82.843863
# poster_path               3.514122         0.000000
# imdb_id                   0.449997         0.000000
# facebook_id              95.742791         0.000000
# instagram_id             98.290307         0.000000
# twitter_id               97.935046         0.000000
# wikidata_id              75.081414         0.000000
# revenue_mojo              0.000000        91.256143
# error                    99.965954         0.000000
# budget_wiki               0.000000        81.037954
# revenue_wiki              0.000000        77.504589
# url_wiki                 73.488661         0.000000
# revenue_fix               0.000000        99.678785
# budget_fix                0.000000        99.924507
# budget_synthetic          0.000000        75.473681
# revenue_synthetic         0.000000        70.661377

# %%
movie = movie[(movie["revenue_synthetic"] != 0) & (movie["budget_synthetic"] != 0)]

# %%
movie[
    [
        "budget",
        "budget_wiki",
        "budget_synthetic",
        "revenue",
        "revenue_mojo",
        "revenue_wiki",
        "revenue_synthetic",
    ]
].describe().drop("count").style.format(
    {
        "budget": "${:,.0f}",
        "budget_wiki": "${:,.0f}",
        "budget_synthetic": "${:,.0f}",
        "revenue": "${:,.0f}",
        "revenue_mojo": "${:,.0f}",
        "revenue_wiki": "${:,.0f}",
        "revenue_synthetic": "${:,.0f}",
    }
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a9bbc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9bbc_level0_col0" class="col_heading level0 col0" >budget</th>
#       <th id="T_a9bbc_level0_col1" class="col_heading level0 col1" >budget_wiki</th>
#       <th id="T_a9bbc_level0_col2" class="col_heading level0 col2" >budget_synthetic</th>
#       <th id="T_a9bbc_level0_col3" class="col_heading level0 col3" >revenue</th>
#       <th id="T_a9bbc_level0_col4" class="col_heading level0 col4" >revenue_mojo</th>
#       <th id="T_a9bbc_level0_col5" class="col_heading level0 col5" >revenue_wiki</th>
#       <th id="T_a9bbc_level0_col6" class="col_heading level0 col6" >revenue_synthetic</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9bbc_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_a9bbc_row0_col0" class="data row0 col0" >$15,751,072</td>
#       <td id="T_a9bbc_row0_col1" class="data row0 col1" >$16,480,430</td>
#       <td id="T_a9bbc_row0_col2" class="data row0 col2" >$17,870,612</td>
#       <td id="T_a9bbc_row0_col3" class="data row0 col3" >$41,714,592</td>
#       <td id="T_a9bbc_row0_col4" class="data row0 col4" >$11,743,013</td>
#       <td id="T_a9bbc_row0_col5" class="data row0 col5" >$45,076,162</td>
#       <td id="T_a9bbc_row0_col6" class="data row0 col6" >$43,862,892</td>
#     </tr>
#     <tr>
#       <th id="T_a9bbc_level0_row1" class="row_heading level0 row1" >std</th>
#       <td id="T_a9bbc_row1_col0" class="data row1 col0" >$29,248,547</td>
#       <td id="T_a9bbc_row1_col1" class="data row1 col1" >$30,872,807</td>
#       <td id="T_a9bbc_row1_col2" class="data row1 col2" >$29,475,042</td>
#       <td id="T_a9bbc_row1_col3" class="data row1 col3" >$118,973,065</td>
#       <td id="T_a9bbc_row1_col4" class="data row1 col4" >$64,936,001</td>
#       <td id="T_a9bbc_row1_col5" class="data row1 col5" >$122,404,824</td>
#       <td id="T_a9bbc_row1_col6" class="data row1 col6" >$119,014,208</td>
#     </tr>
#     <tr>
#       <th id="T_a9bbc_level0_row2" class="row_heading level0 row2" >min</th>
#       <td id="T_a9bbc_row2_col0" class="data row2 col0" >$0</td>
#       <td id="T_a9bbc_row2_col1" class="data row2 col1" >$0</td>
#       <td id="T_a9bbc_row2_col2" class="data row2 col2" >$1</td>
#       <td id="T_a9bbc_row2_col3" class="data row2 col3" >$0</td>
#       <td id="T_a9bbc_row2_col4" class="data row2 col4" >$0</td>
#       <td id="T_a9bbc_row2_col5" class="data row2 col5" >$0</td>
#       <td id="T_a9bbc_row2_col6" class="data row2 col6" >$1</td>
#     </tr>
#     <tr>
#       <th id="T_a9bbc_level0_row3" class="row_heading level0 row3" >25%</th>
#       <td id="T_a9bbc_row3_col0" class="data row3 col0" >$0</td>
#       <td id="T_a9bbc_row3_col1" class="data row3 col1" >$1,708,914</td>
#       <td id="T_a9bbc_row3_col2" class="data row3 col2" >$3,000,000</td>
#       <td id="T_a9bbc_row3_col3" class="data row3 col3" >$0</td>
#       <td id="T_a9bbc_row3_col4" class="data row3 col4" >$0</td>
#       <td id="T_a9bbc_row3_col5" class="data row3 col5" >$1,011,769</td>
#       <td id="T_a9bbc_row3_col6" class="data row3 col6" >$1,372,469</td>
#     </tr>
#     <tr>
#       <th id="T_a9bbc_level0_row4" class="row_heading level0 row4" >50%</th>
#       <td id="T_a9bbc_row4_col0" class="data row4 col0" >$5,000,000</td>
#       <td id="T_a9bbc_row4_col1" class="data row4 col1" >$7,000,000</td>
#       <td id="T_a9bbc_row4_col2" class="data row4 col2" >$8,000,000</td>
#       <td id="T_a9bbc_row4_col3" class="data row4 col3" >$3,800,000</td>
#       <td id="T_a9bbc_row4_col4" class="data row4 col4" >$0</td>
#       <td id="T_a9bbc_row4_col5" class="data row4 col5" >$7,800,000</td>
#       <td id="T_a9bbc_row4_col6" class="data row4 col6" >$7,825,000</td>
#     </tr>
#     <tr>
#       <th id="T_a9bbc_level0_row5" class="row_heading level0 row5" >75%</th>
#       <td id="T_a9bbc_row5_col0" class="data row5 col0" >$19,000,000</td>
#       <td id="T_a9bbc_row5_col1" class="data row5 col1" >$19,600,000</td>
#       <td id="T_a9bbc_row5_col2" class="data row5 col2" >$20,000,000</td>
#       <td id="T_a9bbc_row5_col3" class="data row5 col3" >$30,749,142</td>
#       <td id="T_a9bbc_row5_col4" class="data row5 col4" >$6,783</td>
#       <td id="T_a9bbc_row5_col5" class="data row5 col5" >$35,800,000</td>
#       <td id="T_a9bbc_row5_col6" class="data row5 col6" >$33,157,615</td>
#     </tr>
#     <tr>
#       <th id="T_a9bbc_level0_row6" class="row_heading level0 row6" >max</th>
#       <td id="T_a9bbc_row6_col0" class="data row6 col0" >$379,000,000</td>
#       <td id="T_a9bbc_row6_col1" class="data row6 col1" >$1,107,215,353</td>
#       <td id="T_a9bbc_row6_col2" class="data row6 col2" >$500,000,000</td>
#       <td id="T_a9bbc_row6_col3" class="data row6 col3" >$2,923,706,026</td>
#       <td id="T_a9bbc_row6_col4" class="data row6 col4" >$2,923,706,026</td>
#       <td id="T_a9bbc_row6_col5" class="data row6 col5" >$2,923,000,000</td>
#       <td id="T_a9bbc_row6_col6" class="data row6 col6" >$2,923,706,026</td>
#     </tr>
#   </tbody>
# </table>

# %%
movie["synthetic_ratio"] = movie["revenue_synthetic"] / movie["budget_synthetic"]

# %%
movie[
    [
        "movie_id",
        "title",
        "url_wiki",
        "original_language",
        "revenue",
        "revenue_wiki",
        "revenue_mojo",
        "revenue_synthetic",
        "budget",
        "budget_wiki",
        "budget_synthetic",
        "synthetic_ratio",
    ]
].sort_values(by="synthetic_ratio", ascending=False).to_clipboard()

# %%
movie[["budget", "budget_wiki", "budget_synthetic"]].corr().style.format(
    "{:.2f}"
).background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_1637b_row0_col0, #T_1637b_row1_col1, #T_1637b_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1637b_row0_col1, #T_1637b_row1_col0, #T_1637b_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1637b_row0_col2 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_1637b_row2_col0 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_1637b_row2_col1 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1637b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1637b_level0_col0" class="col_heading level0 col0" >budget</th>
#       <th id="T_1637b_level0_col1" class="col_heading level0 col1" >budget_wiki</th>
#       <th id="T_1637b_level0_col2" class="col_heading level0 col2" >budget_synthetic</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1637b_level0_row0" class="row_heading level0 row0" >budget</th>
#       <td id="T_1637b_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_1637b_row0_col1" class="data row0 col1" >0.78</td>
#       <td id="T_1637b_row0_col2" class="data row0 col2" >0.95</td>
#     </tr>
#     <tr>
#       <th id="T_1637b_level0_row1" class="row_heading level0 row1" >budget_wiki</th>
#       <td id="T_1637b_row1_col0" class="data row1 col0" >0.78</td>
#       <td id="T_1637b_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_1637b_row1_col2" class="data row1 col2" >0.83</td>
#     </tr>
#     <tr>
#       <th id="T_1637b_level0_row2" class="row_heading level0 row2" >budget_synthetic</th>
#       <td id="T_1637b_row2_col0" class="data row2 col0" >0.95</td>
#       <td id="T_1637b_row2_col1" class="data row2 col1" >0.83</td>
#       <td id="T_1637b_row2_col2" class="data row2 col2" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
movie[
    ["revenue", "revenue_mojo", "revenue_wiki", "revenue_synthetic"]
].corr().style.format("{:.2f}").background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_9ef77_row0_col0, #T_9ef77_row1_col1, #T_9ef77_row2_col2, #T_9ef77_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9ef77_row0_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_9ef77_row0_col2 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_9ef77_row0_col3, #T_9ef77_row3_col0 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_9ef77_row1_col0, #T_9ef77_row1_col2, #T_9ef77_row1_col3, #T_9ef77_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9ef77_row2_col0 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_9ef77_row2_col3, #T_9ef77_row3_col2 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_9ef77_row3_col1 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9ef77">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ef77_level0_col0" class="col_heading level0 col0" >revenue</th>
#       <th id="T_9ef77_level0_col1" class="col_heading level0 col1" >revenue_mojo</th>
#       <th id="T_9ef77_level0_col2" class="col_heading level0 col2" >revenue_wiki</th>
#       <th id="T_9ef77_level0_col3" class="col_heading level0 col3" >revenue_synthetic</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ef77_level0_row0" class="row_heading level0 row0" >revenue</th>
#       <td id="T_9ef77_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_9ef77_row0_col1" class="data row0 col1" >0.49</td>
#       <td id="T_9ef77_row0_col2" class="data row0 col2" >0.96</td>
#       <td id="T_9ef77_row0_col3" class="data row0 col3" >0.99</td>
#     </tr>
#     <tr>
#       <th id="T_9ef77_level0_row1" class="row_heading level0 row1" >revenue_mojo</th>
#       <td id="T_9ef77_row1_col0" class="data row1 col0" >0.49</td>
#       <td id="T_9ef77_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_9ef77_row1_col2" class="data row1 col2" >0.48</td>
#       <td id="T_9ef77_row1_col3" class="data row1 col3" >0.50</td>
#     </tr>
#     <tr>
#       <th id="T_9ef77_level0_row2" class="row_heading level0 row2" >revenue_wiki</th>
#       <td id="T_9ef77_row2_col0" class="data row2 col0" >0.96</td>
#       <td id="T_9ef77_row2_col1" class="data row2 col1" >0.48</td>
#       <td id="T_9ef77_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_9ef77_row2_col3" class="data row2 col3" >0.96</td>
#     </tr>
#     <tr>
#       <th id="T_9ef77_level0_row3" class="row_heading level0 row3" >revenue_synthetic</th>
#       <td id="T_9ef77_row3_col0" class="data row3 col0" >0.99</td>
#       <td id="T_9ef77_row3_col1" class="data row3 col1" >0.50</td>
#       <td id="T_9ef77_row3_col2" class="data row3 col2" >0.96</td>
#       <td id="T_9ef77_row3_col3" class="data row3 col3" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
movie[["runtime", "budget", "revenue"]].describe().drop("count").style.format(
    {"runtime": "{:.0f}", "budget": "${:,.0f}", "revenue": "${:,.0f}"}
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_825ce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_825ce_level0_col0" class="col_heading level0 col0" >runtime</th>
#       <th id="T_825ce_level0_col1" class="col_heading level0 col1" >budget</th>
#       <th id="T_825ce_level0_col2" class="col_heading level0 col2" >revenue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_825ce_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_825ce_row0_col0" class="data row0 col0" >109</td>
#       <td id="T_825ce_row0_col1" class="data row0 col1" >$15,751,072</td>
#       <td id="T_825ce_row0_col2" class="data row0 col2" >$41,714,592</td>
#     </tr>
#     <tr>
#       <th id="T_825ce_level0_row1" class="row_heading level0 row1" >std</th>
#       <td id="T_825ce_row1_col0" class="data row1 col0" >21</td>
#       <td id="T_825ce_row1_col1" class="data row1 col1" >$29,248,547</td>
#       <td id="T_825ce_row1_col2" class="data row1 col2" >$118,973,065</td>
#     </tr>
#     <tr>
#       <th id="T_825ce_level0_row2" class="row_heading level0 row2" >min</th>
#       <td id="T_825ce_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_825ce_row2_col1" class="data row2 col1" >$0</td>
#       <td id="T_825ce_row2_col2" class="data row2 col2" >$0</td>
#     </tr>
#     <tr>
#       <th id="T_825ce_level0_row3" class="row_heading level0 row3" >25%</th>
#       <td id="T_825ce_row3_col0" class="data row3 col0" >94</td>
#       <td id="T_825ce_row3_col1" class="data row3 col1" >$0</td>
#       <td id="T_825ce_row3_col2" class="data row3 col2" >$0</td>
#     </tr>
#     <tr>
#       <th id="T_825ce_level0_row4" class="row_heading level0 row4" >50%</th>
#       <td id="T_825ce_row4_col0" class="data row4 col0" >104</td>
#       <td id="T_825ce_row4_col1" class="data row4 col1" >$5,000,000</td>
#       <td id="T_825ce_row4_col2" class="data row4 col2" >$3,800,000</td>
#     </tr>
#     <tr>
#       <th id="T_825ce_level0_row5" class="row_heading level0 row5" >75%</th>
#       <td id="T_825ce_row5_col0" class="data row5 col0" >118</td>
#       <td id="T_825ce_row5_col1" class="data row5 col1" >$19,000,000</td>
#       <td id="T_825ce_row5_col2" class="data row5 col2" >$30,749,142</td>
#     </tr>
#     <tr>
#       <th id="T_825ce_level0_row6" class="row_heading level0 row6" >max</th>
#       <td id="T_825ce_row6_col0" class="data row6 col0" >360</td>
#       <td id="T_825ce_row6_col1" class="data row6 col1" >$379,000,000</td>
#       <td id="T_825ce_row6_col2" class="data row6 col2" >$2,923,706,026</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_and_export_categorical_distribution(keywords, "keyword_name", "keyword", 300, print_stats=True, filename_prefix="step_1")
# Out:
#                       grouped   total
# 0                       Other  174187
# 1              woman director    4570
# 2      based on novel or book    2064
# 3                      murder    1709
# 4                   biography     986
# 5                     revenge     941
# 6                   gay theme     929
# 7                        lgbt     850
# 8         based on true story     816
# 9                        love     714
# 10               martial arts     683
# 11              new york city     680
# 12                     sports     661
# 13                 friendship     631
# 14                     sequel     621
# 15              coming of age     576
# 16                     police     564
# 17                      drugs     545
# 18              serial killer     544
# 19  parent child relationship     535
# 20                    musical     500
# 21               world war ii     498
# 22                     family     497
# 23                 kidnapping     493
# 24                       rape     485
# 25                high school     448
# 26       sibling relationship     428
# 27    los angeles, california     415
# 28       duringcreditsstinger     392
# 29                     prison     392
# 30                     remake     388
# 31                    suicide     377
# 32              paris, france     367
# 33                    romance     362
# 34                      death     359
# 35                      1970s     358
# 36                    slasher     352
# 37  husband wife relationship     351
# 38          loss of loved one     350
# 39                 prostitute     339
# 40                  christmas     336
# 41                dark comedy     332
# 42                  detective     331
# 43            london, england     331
# 44                 small town     331
# 45                      japan     328
# 46                 infidelity     315
# 47                   gangster     313
# 48                   politics     310
# 49               erotic movie     309
# 50                   neo-noir     308
# 51                    vampire     306
# 52                  terrorism     303
# 53                     zombie     301
#                       grouped   total
# 0                       Other  174187
# 1              woman director    4570
# 2      based on novel or book    2064
# 3                      murder    1709
# 4                   biography     986
# 5                     revenge     941
# 6                   gay theme     929
# 7                        lgbt     850
# 8         based on true story     816
# 9                        love     714
# 10               martial arts     683
# 11              new york city     680
# 12                     sports     661
# 13                 friendship     631
# 14                     sequel     621
# 15              coming of age     576
# 16                     police     564
# 17                      drugs     545
# 18              serial killer     544
# 19  parent child relationship     535
# 20                    musical     500
# 21               world war ii     498
# 22                     family     497
# 23                 kidnapping     493
# 24                       rape     485
# 25                high school     448
# 26       sibling relationship     428
# 27    los angeles, california     415
# 28       duringcreditsstinger     392
# 29                     prison     392
# 30                     remake     388
# 31                    suicide     377
# 32              paris, france     367
# 33                    romance     362
# 34                      death     359
# 35                      1970s     358
# 36                    slasher     352
# 37  husband wife relationship     351
# 38          loss of loved one     350
# 39                 prostitute     339
# 40                  christmas     336
# 41                dark comedy     332
# 42                  detective     331
# 43            london, england     331
# 44                 small town     331
# 45                      japan     328
# 46                 infidelity     315
# 47                   gangster     313
# 48                   politics     310
# 49               erotic movie     309
# 50                   neo-noir     308
# 51                    vampire     306
# 52                  terrorism     303
# 53                     zombie     301

# %%
plot_and_export_categorical_distribution(genres, "genre_name", "genre", 300, print_stats=True, filename_prefix="step_1")
# Out:
#             grouped  total
# 0             Drama  33072
# 1            Comedy  20252
# 2          Thriller   9656
# 3           Romance   8990
# 4            Action   7922
# 5             Crime   6396
# 6            Horror   6285
# 7       Documentary   6124
# 8         Adventure   3943
# 9           Mystery   3097
# 10           Family   3060
# 11  Science Fiction   2895
# 12          Fantasy   2633
# 13          History   2534
# 14            Music   1978
# 15              War   1738
# 16         TV Movie   1044
# 17          Western    716
# 18        Animation    595
#             grouped  total
# 0             Drama  33072
# 1            Comedy  20252
# 2          Thriller   9656
# 3           Romance   8990
# 4            Action   7922
# 5             Crime   6396
# 6            Horror   6285
# 7       Documentary   6124
# 8         Adventure   3943
# 9           Mystery   3097
# 10           Family   3060
# 11  Science Fiction   2895
# 12          Fantasy   2633
# 13          History   2534
# 14            Music   1978
# 15              War   1738
# 16         TV Movie   1044
# 17          Western    716
# 18        Animation    595

# %%
plot_and_export_categorical_distribution(
    production_companies, "company_name", "company", 300, print_stats=True, filename_prefix="step_1")
# Out:
#                   grouped   total
# 0                   Other  120955
# 1   Warner Bros. Pictures     813
# 2                  Canal+     802
# 3      Universal Pictures     764
# 4       Columbia Pictures     624
# 5      Paramount Pictures     605
# 6        20th Century Fox     567
# 7                 Mosfilm     487
# 8                     ZDF     483
# 9                     RAI     434
# 10                    CNC     424
# 11        France 2 Cinéma     388
# 12      Film4 Productions     354
# 13    Metro-Goldwyn-Mayer     352
# 14   TF1 Films Production     345
# 15                    ARD     313
# 16        New Line Cinema     310
# 17        France 3 Cinéma     305
#                   grouped   total
# 0                   Other  120955
# 1   Warner Bros. Pictures     813
# 2                  Canal+     802
# 3      Universal Pictures     764
# 4       Columbia Pictures     624
# 5      Paramount Pictures     605
# 6        20th Century Fox     567
# 7                 Mosfilm     487
# 8                     ZDF     483
# 9                     RAI     434
# 10                    CNC     424
# 11        France 2 Cinéma     388
# 12      Film4 Productions     354
# 13    Metro-Goldwyn-Mayer     352
# 14   TF1 Films Production     345
# 15                    ARD     313
# 16        New Line Cinema     310
# 17        France 3 Cinéma     305

# %%
plot_and_export_categorical_distribution(cast, "name", "actor", 100, print_stats=True,  filename_prefix="step_1")
# Out:
#                  grouped    total
# 0                  Other  1231898
# 1       Gérard Depardieu      167
# 2          Carla Mancini      162
# 3            Danny Trejo      142
# 4           Eric Roberts      129
# 5      Samuel L. Jackson      121
# 6         Michael Madsen      117
# 7            Jackie Chan      117
# 8   Luigi Antonio Guerra      116
# 9         Michel Piccoli      114
# 10              Udo Kier      112
# 11        Michel Galabru      110
# 12     Donald Sutherland      110
# 13         Harvey Keitel      107
# 14            Eric Tsang      106
# 15        Robert De Niro      105
# 16              Lam Suet      102
# 17      Amitabh Bachchan      101
# 18      Malcolm McDowell      101
# 19          Willem Dafoe      101
# 20       Lance Henriksen      100
# 21          Bruce Willis      100
# 22      Isabelle Huppert      100
#                  grouped    total
# 0                  Other  1231898
# 1       Gérard Depardieu      167
# 2          Carla Mancini      162
# 3            Danny Trejo      142
# 4           Eric Roberts      129
# 5      Samuel L. Jackson      121
# 6         Michael Madsen      117
# 7            Jackie Chan      117
# 8   Luigi Antonio Guerra      116
# 9         Michel Piccoli      114
# 10              Udo Kier      112
# 11        Michel Galabru      110
# 12     Donald Sutherland      110
# 13         Harvey Keitel      107
# 14            Eric Tsang      106
# 15        Robert De Niro      105
# 16              Lam Suet      102
# 17      Amitabh Bachchan      101
# 18      Malcolm McDowell      101
# 19          Willem Dafoe      101
# 20       Lance Henriksen      100
# 21          Bruce Willis      100
# 22      Isabelle Huppert      100

# %%
plot_and_export_categorical_distribution(
    collections, "collection_name", "collection", 10, print_stats=True, filename_prefix="step_1")
# Out:
#                             grouped  total
# 0                             Other   5700
# 1                   Tora-san Series     44
# 2            Os Trapalhões: Coleção     36
# 3      Troublesome Night Collection     19
# 4             James Bond Collection     18
# 5               Carry On Collection     16
# 6             Witchcraft Collection     16
# 7               Les Charlots - Saga     15
# 8         Johan Falk GSI Collection     14
# 9        Black Emanuelle Collection     13
# 10             Varg Veum Collection     12
# 11        The Olsen Gang Collection     12
# 12     Schoolgirl Report Collection     12
# 13           Olsenbanden Collection     12
# 14                    Roland Hassel     11
# 15          Nico Giraldi Collection     11
# 16        Bullets, Bombs, and Babes     11
# 17                 Los Superagentes     11
# 18       Friday the 13th Collection     11
# 19        Father of Four Collection     11
# 20  Exhibition on Screen Collection     11
# 21   Young and Dangerous Collection     11
# 22         Puppet Master Collection     10
# 23        Lemon Popsicle Collection     10
# 24            Hellraiser Collection     10
# 25              Fantozzi Collection     10
#                             grouped  total
# 0                             Other   5700
# 1                   Tora-san Series     44
# 2            Os Trapalhões: Coleção     36
# 3      Troublesome Night Collection     19
# 4             James Bond Collection     18
# 5               Carry On Collection     16
# 6             Witchcraft Collection     16
# 7               Les Charlots - Saga     15
# 8         Johan Falk GSI Collection     14
# 9        Black Emanuelle Collection     13
# 10             Varg Veum Collection     12
# 11        The Olsen Gang Collection     12
# 12     Schoolgirl Report Collection     12
# 13           Olsenbanden Collection     12
# 14                    Roland Hassel     11
# 15          Nico Giraldi Collection     11
# 16        Bullets, Bombs, and Babes     11
# 17                 Los Superagentes     11
# 18       Friday the 13th Collection     11
# 19        Father of Four Collection     11
# 20  Exhibition on Screen Collection     11
# 21   Young and Dangerous Collection     11
# 22         Puppet Master Collection     10
# 23        Lemon Popsicle Collection     10
# 24            Hellraiser Collection     10
# 25              Fantozzi Collection     10

# %%
plot_and_export_categorical_distribution(spoken_languages, "english_name", "language", 100, print_stats=True, filename_prefix="step_1")
# Out:
#            grouped  total
# 0          English  27784
# 1           French   7808
# 2          Spanish   7123
# 3          Italian   5545
# 4           German   5521
# 5          Russian   3263
# 6         Japanese   2303
# 7            Other   2174
# 8       Portuguese   2114
# 9         Mandarin   1914
# 10           Hindi   1244
# 11          Arabic   1204
# 12          Korean   1161
# 13       Cantonese   1155
# 14         Swedish    981
# 15          Danish    949
# 16          Polish    923
# 17         Turkish    884
# 18          Hebrew    866
# 19           Dutch    746
# 20           Czech    638
# 21       Hungarian    503
# 22       Norwegian    495
# 23      Indonesian    424
# 24         Finnish    415
# 25         Persian    395
# 26           Greek    380
# 27        Romanian    363
# 28            Thai    328
# 29         Tagalog    302
# 30         Serbian    299
# 31  Serbo-Croatian    264
# 32         Catalan    240
# 33           Tamil    227
# 34          Telugu    197
# 35        Croatian    189
# 36           Latin    180
# 37       Ukrainian    166
# 38       Bulgarian    165
# 39         Bengali    150
# 40       Malayalam    141
# 41      Vietnamese    135
# 42       Slovenian    130
# 43          Slovak    127
# 44       Icelandic    123
# 45            Urdu    107
# 46       Afrikaans    106
# 47        Estonian    102
# 48        Albanian    101
#            grouped  total
# 0          English  27784
# 1           French   7808
# 2          Spanish   7123
# 3          Italian   5545
# 4           German   5521
# 5          Russian   3263
# 6         Japanese   2303
# 7            Other   2174
# 8       Portuguese   2114
# 9         Mandarin   1914
# 10           Hindi   1244
# 11          Arabic   1204
# 12          Korean   1161
# 13       Cantonese   1155
# 14         Swedish    981
# 15          Danish    949
# 16          Polish    923
# 17         Turkish    884
# 18          Hebrew    866
# 19           Dutch    746
# 20           Czech    638
# 21       Hungarian    503
# 22       Norwegian    495
# 23      Indonesian    424
# 24         Finnish    415
# 25         Persian    395
# 26           Greek    380
# 27        Romanian    363
# 28            Thai    328
# 29         Tagalog    302
# 30         Serbian    299
# 31  Serbo-Croatian    264
# 32         Catalan    240
# 33           Tamil    227
# 34          Telugu    197
# 35        Croatian    189
# 36           Latin    180
# 37       Ukrainian    166
# 38       Bulgarian    165
# 39         Bengali    150
# 40       Malayalam    141
# 41      Vietnamese    135
# 42       Slovenian    130
# 43          Slovak    127
# 44       Icelandic    123
# 45            Urdu    107
# 46       Afrikaans    106
# 47        Estonian    102
# 48        Albanian    101

# %%
plot_and_export_categorical_distribution(production_countries, "name", "country", 500, print_stats=True, filename_prefix="step_1")
# Out:
#                      grouped  total
# 0   United States of America  18192
# 1                      Other  10090
# 2                     France   7470
# 3                    Germany   5557
# 4                      Italy   5289
# 5             United Kingdom   4353
# 6                      Spain   3120
# 7                     Canada   2690
# 8                      Japan   2103
# 9                      India   1811
# 10                 Argentina   1581
# 11                    Brazil   1547
# 12                 Hong Kong   1491
# 13                    Russia   1248
# 14              Soviet Union   1243
# 15                   Denmark   1211
# 16                    Sweden   1163
# 17               South Korea   1098
# 18                   Belgium   1097
# 19                     China   1032
# 20                    Mexico   1013
# 21               Netherlands    880
# 22               Switzerland    876
# 23                 Australia    854
# 24                    Poland    795
# 25                    Israel    715
# 26                    Turkey    666
# 27                    Norway    624
# 28                   Austria    621
# 29                   Finland    538
# 30            Czech Republic    535
# 31                  Portugal    516
#                      grouped  total
# 0   United States of America  18192
# 1                      Other  10090
# 2                     France   7470
# 3                    Germany   5557
# 4                      Italy   5289
# 5             United Kingdom   4353
# 6                      Spain   3120
# 7                     Canada   2690
# 8                      Japan   2103
# 9                      India   1811
# 10                 Argentina   1581
# 11                    Brazil   1547
# 12                 Hong Kong   1491
# 13                    Russia   1248
# 14              Soviet Union   1243
# 15                   Denmark   1211
# 16                    Sweden   1163
# 17               South Korea   1098
# 18                   Belgium   1097
# 19                     China   1032
# 20                    Mexico   1013
# 21               Netherlands    880
# 22               Switzerland    876
# 23                 Australia    854
# 24                    Poland    795
# 25                    Israel    715
# 26                    Turkey    666
# 27                    Norway    624
# 28                   Austria    621
# 29                   Finland    538
# 30            Czech Republic    535
# 31                  Portugal    516
